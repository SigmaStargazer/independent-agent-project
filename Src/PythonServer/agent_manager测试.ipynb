# %%
from agent_framwork.managers.agent_manager  import Agent_manager
from typing_extensions import TypedDict

# %%
list(Agent_manager().agents.keys())
# Out:
# ['小明', '小红']

# %%
[agent.name for agent in Agent_manager().agents.values()]
# Out:
# ['小明', '小红']

# %%
class State(TypedDict):
    messages: list
    name: str
    description: str

# %%
aaa =
