# %% [markdown]
# 实现方式：https://www.cnblogs.com/huchong/p/8244279.html

# %%
import threading

# %%
import threading

# 通过继承Singleton创建单例
class Singleton:
    _instance = None
    _lock = threading.Lock()

    def __new__(cls, *args, **kwargs):
        if cls._instance is None:
            with cls._lock:
                if cls._instance is None:
                    cls._instance = super(Singleton, cls).__new__(cls)
        return cls._instance

# 通过@singleton注解来创建单例
def singleton(cls):
    instances = {}
    lock = threading.Lock()
    
    def wrapper(*args, **kwargs):
        if cls not in instances:
            with lock:
                if cls not in instances:
                    instances[cls] = cls(*args, **kwargs)
        return instances[cls]
    
    return wrapper

# %%
obj1 = Singleton()
obj2 = Singleton()

# %%
obj1

# %%
obj2

# %%
class AAASystem(Singleton):
    def __init__(self,name):
        self.name = name

# %%
AAASystem("AAA").name
# Out:
# 'AAA'

# %%
bbb = AAASystem("BBB")
bbb.name
# Out:
# 'BBB'

# %%
ccc = AAASystem("CCC")
ccc.name
# Out:
# 'CCC'

# %%
bbb.name
# Out:
# 'CCC'

# %%
@singleton
class BBBSystem(Singleton):
    def __init__(self,name):
        self.name = name

# %%
BBBSystem("AAA").name
# Out:
# 'AAA'

# %%
bbb = BBBSystem("BBB")
bbb.name
# Out:
# 'AAA'

# %%
bbb.name = 'BBB'
bbb.name
# Out:
# 'BBB'

# %%
BBBSystem("AAA").name
# Out:
# 'BBB'

# %%
@singleton
class CCCSystem(Singleton):
    def __init__(self,name):
        self.name = name

# %%
CCCSystem("CCC").name
# Out:
# 'CCC'

# %%
BBBSystem("AAA").name
# Out:
# 'BBB'
